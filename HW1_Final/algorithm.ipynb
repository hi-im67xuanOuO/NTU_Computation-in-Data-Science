# %% [markdown]
# # 資料匯入與整理

# %%
import csv
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dist.csv")
df.head()
# Out:
#                    Unnamed: 0  台北市南港區中坡南路47號1樓  台北市南港區研究院路二段128號1樓(學術活動中心)  \
# 0             台北市南港區中坡南路47號1樓              0.0                       580.0
# 1  台北市南港區研究院路二段128號1樓(學術活動中心)            550.0                         0.0
# 2            台北市南港區經貿二路186號2樓            590.0                       300.0
# 3          台北市南港區西新里南港路三段3號1樓            220.0                       460.0
# 4             台北市南港區玉成街150號1樓            350.0                       550.0
#
#    台北市南港區經貿二路186號2樓  台北市南港區西新里南港路三段3號1樓  台北市南港區玉成街150號1樓  台北市南港區向陽路166號1樓  \
# 0             480.0               250.0            350.0            290.0
# 1             250.0               440.0            530.0            480.0
# 2               0.0               270.0            560.0            300.0
# 3             310.0                 0.0            200.0            400.0
# 4             450.0               230.0              0.0            270.0
#
# ...

# %%
stores = [{"name": "中坡", "address": "台北市南港區中坡南路47號1樓"},
{"name": "中研", "address": "台北市南港區研究院路二段128號1樓(學術活動中心)"},
{"name": "中貿", "address": "台北市南港區經貿二路186號2樓"},
{"name": "玉成", "address": "台北市南港區西新里南港路三段3號1樓"},
{"name": "玉德", "address": "台北市南港區玉成街150號1樓"},
{"name": "向揚", "address": "台北市南港區向陽路166號1樓"},
{"name": "庄研", "address": "台北市南港區研究院路二段152號"},
{"name": "佳樂", "address": "台北市南港區南港路一段303號305號307號1樓"},
{"name": "忠陽", "address": "台北市南港區忠孝東路六段465號1樓"},
{"name": "昆陽", "address": "台北市南港區忠孝東路六段448號"},
{"name": "林坊", "address": "台北市南港區東新街80巷1號"},
{"name": "研究", "address": "台北市南港區研究院路二段14號"},
{"name": "胡適", "address": "台北市南港區研究院路二段94號96號98巷1號"},
{"name": "重陽", "address": "台北市南港區重陽路179號181號1樓"},
{"name": "香城", "address": "台北市南港區南港路一段167號1樓"},
{"name": "凱松", "address": "台北市南港區八德路四段778號780號"},
{"name": "港泰", "address": "台北市南港區忠孝東路七段359號1樓"},
{"name": "港高鐵", "address": "台北市南港區南港路一段313號B2"},
{"name": "港捷", "address": "台北市南港區經貿二路1號"},
{"name": "港勝", "address": "台北市南港區經貿二路2號B1樓"},
{"name": "港運", "address": "台北市南港區玉成街69號1樓"},
{"name": "港德", "address": "台北市南港區福德街373巷25號"},
{"name": "港興", "address": "台北市南港區興華路119號121號123號125號"},
{"name": "港環球", "address": "台北市南港區忠孝東路七段371號B2"},
{"name": "港麗", "address": "台北市南港區忠孝東路七段369號2樓"},
{"name": "華技", "address": "台北市南港區研究院路三段72號74號1樓"},
{"name": "雄強", "address": "台北市南港區忠孝東路六段276號"},
{"name": "慈愛", "address": "台北市南港區重陽路164號"},
{"name": "新福玉", "address": "台北市南港區成福路145號147號"},
{"name": "經貿", "address": "台北市南港區三重路19號1樓"},
{"name": "聯成", "address": "台北市南港區聯成里昆陽街150-1號150-3號"},
{"name": "聯坊", "address": "台北市南港區東新街118巷1號"},
{"name": "馥樺", "address": "台北市南港區三重路23號1樓"},
{"name": "鵬馳", "address": "台北市南港區南港路三段49-1號"},
{"name": "耀港", "address": "台北市南港區研究院路一段99號1樓之14"},
{"name": "鑫貿", "address": "台北市南港區經貿二路168號4樓"}
]

# %%
store_name = []
for i in range(len(stores)):
    store_name.append(stores[i]["name"])
print(store_name)
print(len(store_name))
# Out:
# ['中坡', '中研', '中貿', '玉成', '玉德', '向揚', '庄研', '佳樂', '忠陽', '昆陽', '林坊', '研究', '胡適', '重陽', '香城', '凱松', '港泰', '港高鐵', '港捷', '港勝', '港運', '港德', '港興', '港環球', '港麗', '華技', '雄強', '慈愛', '新福玉', '經貿', '聯成', '聯坊', '馥樺', '鵬馳', '耀港', '鑫貿']
# 36

# %%
df = df.drop(['Unnamed: 0'], axis=1)
df.head()
# Out:
#    台北市南港區中坡南路47號1樓  台北市南港區研究院路二段128號1樓(學術活動中心)  台北市南港區經貿二路186號2樓  \
# 0              0.0                       580.0             480.0
# 1            550.0                         0.0             250.0
# 2            590.0                       300.0               0.0
# 3            220.0                       460.0             310.0
# 4            350.0                       550.0             450.0
#
#    台北市南港區西新里南港路三段3號1樓  台北市南港區玉成街150號1樓  台北市南港區向陽路166號1樓  台北市南港區研究院路二段152號  \
# 0               250.0            350.0            290.0             580.0
# 1               440.0            530.0            480.0             130.0
# 2               270.0            560.0            300.0             290.0
# 3                 0.0            200.0            400.0             450.0
# 4               230.0              0.0            270.0             550.0
#
#    台北市南港區南港路一段303號305號307號1樓  台北市南港區忠孝東路六段465號1樓  台北市南港區忠孝東路六段448號  ...  \
# ...

# %%
df_new = pd.DataFrame(np.array(df),columns=store_name)
df_new.head()
# Out:
#       中坡     中研     中貿     玉成     玉德     向揚     庄研     佳樂     忠陽     昆陽  ...  \
# 0    0.0  580.0  480.0  250.0  350.0  290.0  580.0  340.0  170.0  170.0  ...
# 1  550.0    0.0  250.0  440.0  530.0  480.0  130.0  280.0  400.0  380.0  ...
# 2  590.0  300.0    0.0  270.0  560.0  300.0  290.0  130.0  300.0  300.0  ...
# 3  220.0  460.0  310.0    0.0  200.0  400.0  450.0  160.0  450.0  500.0  ...
# 4  350.0  550.0  450.0  230.0    0.0  270.0  550.0  320.0  150.0  150.0  ...
#
#       雄強     慈愛    新福玉     經貿     聯成     聯坊     馥樺     鵬馳     耀港     鑫貿
# 0  120.0  300.0  500.0  400.0  190.0  650.0  450.0  200.0  410.0  460.0
# 1  440.0  370.0  580.0  240.0  390.0  480.0  270.0  460.0  190.0  240.0
# 2  360.0  170.0  500.0  650.0  310.0  400.0  250.0  300.0  900.0  130.0
# 3  900.0  950.0  230.0  220.0  650.0  180.0  250.0  260.0  290.0  300.0
# 4  900.0  280.0  650.0  380.0  140.0  500.0  420.0  180.0  380.0  440.0
#
# [5 rows x 36 columns]

# %%
df = df_new.div(100).round(2)
df.head()
# Out:
#     中坡   中研   中貿   玉成   玉德   向揚   庄研   佳樂   忠陽   昆陽  ...   雄強   慈愛  新福玉   經貿  \
# 0  0.0  5.8  4.8  2.5  3.5  2.9  5.8  3.4  1.7  1.7  ...  1.2  3.0  5.0  4.0
# 1  5.5  0.0  2.5  4.4  5.3  4.8  1.3  2.8  4.0  3.8  ...  4.4  3.7  5.8  2.4
# 2  5.9  3.0  0.0  2.7  5.6  3.0  2.9  1.3  3.0  3.0  ...  3.6  1.7  5.0  6.5
# 3  2.2  4.6  3.1  0.0  2.0  4.0  4.5  1.6  4.5  5.0  ...  9.0  9.5  2.3  2.2
# 4  3.5  5.5  4.5  2.3  0.0  2.7  5.5  3.2  1.5  1.5  ...  9.0  2.8  6.5  3.8
#
#     聯成   聯坊   馥樺   鵬馳   耀港   鑫貿
# 0  1.9  6.5  4.5  2.0  4.1  4.6
# 1  3.9  4.8  2.7  4.6  1.9  2.4
# 2  3.1  4.0  2.5  3.0  9.0  1.3
# 3  6.5  1.8  2.5  2.6  2.9  3.0
# 4  1.4  5.0  4.2  1.8  3.8  4.4
#
# [5 rows x 36 columns]

# %%
col = df.columns
col
# Out:
# Index(['中坡', '中研', '中貿', '玉成', '玉德', '向揚', '庄研', '佳樂', '忠陽', '昆陽', '林坊', '研究',
#        '胡適', '重陽', '香城', '凱松', '港泰', '港高鐵', '港捷', '港勝', '港運', '港德', '港興',
#        '港環球', '港麗', '華技', '雄強', '慈愛', '新福玉', '經貿', '聯成', '聯坊', '馥樺', '鵬馳',
#        '耀港', '鑫貿'],
#       dtype='object')

# %%
dist_list = []
for i in col:
    dist_list.append(df[i].tolist())

# %%
dist_list
# Out:
# [[0.0,
#   5.5,
#   5.9,
#   2.2,
#   3.5,
#   2.4,
#   5.6,
#   3.4,
#   2.0,
#   1.7,
#   6.5,
#   4.5,
#   4.9,
#   2.8,
#   3.9,
#   1.0,
#   3.3,
#   3.1,
#   4.4,
#   4.3,
#   8.5,
#   1.0,
#   3.4,
#   3.1,
#   3.0,
#   6.2,
#   1.2,
#   3.0,
#   5.0,
#   4.0,
#   1.8,
#   6.5,
#   4.4,
#   2.0,
#   4.1,
#   4.7],
#  [5.8,
#   0.0,
#   3.0,
#   4.6,
#   5.5,
#   4.5,
#   1.3,
#   2.9,
#   4.1,
#   4.7,
#   5.2,
#   1.0,
#   6.5,
#   4.2,
#   2.4,
#   5.7,
#   2.8,
#   3.2,
#   2.2,
#   2.1,
#   5.7,
#   5.7,
#   3.4,
#   2.7,
#   3.0,
#   1.9,
#   5.1,
#   4.0,
#   5.7,
#   2.5,
#   4.2,
#   5.2,
#   2.7,
#   4.8,
#   1.7,
#   2.5],
#  [4.8,
#   2.5,
#   0.0,
#   3.1,
#   4.5,
#   3.0,
#   2.6,
#   1.5,
#   3.0,
#   3.6,
#   4.2,
#   1.4,
#   1.8,
#   2.3,
#   7.5,
#   4.5,
#   1.8,
#   1.8,
#   4.5,
#   4.0,
#   4.3,
#   4.7,
#   1.9,
#   1.7,
#   2.0,
#   3.2,
#   4.1,
#   2.0,
#   4.7,
#   6.5,
#   3.1,
#   4.2,
#   2.5,
#   3.3,
#   9.0,
#   1.3],
#  [2.5,
#   4.4,
# ...

# %%
print(len(dist_list))
# Out:
# 36

# %% [markdown]
# # Hill Climbing

# %%
from random import *
import random
import numpy as np
from matplotlib import pyplot
import math
from pprint import pprint

# =========================== hill_climbing ===========================

def randomSolution(tsp):
    cities = [num for num in range(1,36)]
    solution = []
    solution.append(8)
    for i in range(len(tsp)-1):
        randomCity = cities[random.randint(0, len(cities) - 1)]
        solution.append(randomCity)
        cities.remove(randomCity)
    return solution

def routeLength(tsp, solution):
    routeLength = 0
    for i in range(len(solution)):
        routeLength += tsp[solution[i - 1]][solution[i]]
    return routeLength

def getNeighbours(solution):
    neighbours = []
    for i in range(1,len(solution)):
        for j in range(i + 1, len(solution)):
            neighbour = solution.copy()
            neighbour[i] = solution[j]
            neighbour[j] = solution[i]
            neighbours.append(neighbour)
    return neighbours

def getBestNeighbour(tsp, neighbours, time):
    bestRouteLength = routeLength(tsp, neighbours[0])
    bestNeighbour = neighbours[0]
    for neighbour in neighbours:
        currentRouteLength = routeLength(tsp, neighbour)
        if currentRouteLength < bestRouteLength:
            bestRouteLength = currentRouteLength
            bestNeighbour = neighbour
        time+=1
        #print(time)
    return bestNeighbour, bestRouteLength, time

def hillClimbing(tsp):
    result = []
    time = 1
    
    currentSolution = randomSolution(tsp)
    currentRouteLength = routeLength(tsp, currentSolution)
    neighbours = getNeighbours(currentSolution)
    
    bestNeighbour = neighbours[0] 
    bestNeighbourRouteLength = routeLength(tsp, bestNeighbour) 

    while time<=60:
        neighbours = getNeighbours(currentSolution)

        random_ = random.randrange(0, len(neighbours))
        neighbor = neighbours[random_]
        
        RouteLength = routeLength(tsp, neighbor)
        if RouteLength <= bestNeighbourRouteLength:
            bestNeighbourRouteLength = RouteLength
            currentSolution = neighbor # 從現在位置繼續找
           
        result.append(bestNeighbourRouteLength)
        time += 1
        #print("time：",time)


    return currentSolution, bestNeighbourRouteLength, result

# %% [markdown]
# # Random Walk

# %%
# =========================== random_walk ===========================

def randomSolution_2(tsp):
    cities = [num for num in range(1,36)]
    solution = []
    solution.append(8)
    for i in range(len(tsp)-1):
        randomCity = cities[random.randint(0, len(cities) - 1)]
        solution.append(randomCity)
        cities.remove(randomCity)
    return solution

def routeLength_2(tsp, solution):
    routeLength = 0
    for i in range(len(solution)):
        routeLength += tsp[solution[i - 1]][solution[i]]
    return routeLength

def getNeighbours_2(solution):
    neighbours = []
    for i in range(1,len(solution)):
        for j in range(i + 1, len(solution)):
            neighbour = solution.copy()
            neighbour[i] = solution[j]
            neighbour[j] = solution[i]
            neighbours.append(neighbour)
    return neighbours

def random_walk(tsp):
    result = []
    time = 1
    
    currentSolution = randomSolution_2(tsp)
    currentRouteLength = routeLength_2(tsp, currentSolution)
    neighbours = getNeighbours_2(currentSolution)

    random_ = random.randrange(0, len(neighbours))
    neighbor = neighbours[random_]
    RouteLength = routeLength_2(tsp, neighbor)
    
    bestNeighbour = neighbor
    bestNeighbourRouteLength = RouteLength
    BEST = bestNeighbour # 初始化最佳解
    BEST_LENGTH = bestNeighbourRouteLength # 初始化最佳解長度
    
    while time<=60:
        currentSolution = bestNeighbour
        currentRouteLength = bestNeighbourRouteLength

        if (currentRouteLength < BEST_LENGTH):
            BEST = currentSolution
            BEST_LENGTH = currentRouteLength

        result.append(BEST_LENGTH)
        
        neighbours = getNeighbours_2(currentSolution)
        random_ = random.randrange(0, len(neighbours))
        bestNeighbour = neighbours[random_]
        bestNeighbourRouteLength = routeLength_2(tsp, bestNeighbour)

        #result.append(currentRouteLength)
        time += 1
        #print("time：",time)
    
    return BEST, BEST_LENGTH, result

# %% [markdown]
# # Tabu Search

# %%
# =========================== tabu_search ===========================

def path_length(path, distance):
    cities_pairs = zip(path, path[1:])
    consecutive_distances = [(distance[a][b]) for (a, b) in cities_pairs]
    return round(sum(consecutive_distances), 2)


def tabu_search(distance):
    ilosc = 36 # 城市個數
    iter_ = 1

    pbest = [n for n in range(ilosc)]
    pbest_x = pbest
    pbest_y = path_length(pbest_x, distance)
    pcur_x = pbest_x
    pcur_y = pbest_y
    tabu = []
    moveb = []
    score = []

    while iter_<= 60:
        pnew = []
        for i in range(1, len(pbest_x)-1):
            for j in range(2, len(pbest_x)-1):
                if (i != j) and (i < j):
                    acopy = pbest_x
                    acopy[i], acopy[j] = acopy[j], acopy[i]
                    acopy_ = acopy
                    length = path_length( acopy_,distance )
                    move = [i,j]
                    if ( ( (moveb not in tabu) ) and ( ( length<path_length(pnew,distance) ) or ( pnew==[] ) ) or (length<=pbest_y) ):
                        if pnew != []:
                            pnew = []
                            for i in acopy_:
                                pnew.append(i)
                        else:
                            for i in acopy_:
                                pnew.append(i)
                        moveb = move
                        
        pcur_x = pnew
        if pcur_x!=[]:
            if path_length(pcur_x,distance) <= path_length(pbest_x,distance):
                pbest_x = pcur_x
                pbest_y = path_length(pcur_x,distance)
                score.append(pbest_y)
            if moveb not in tabu:
                tabu.append(moveb)
            if len(tabu) >= 10:
                tabu.pop(0)

            iter_ += 1
            if iter_ >= 100:
                break
            #else:
                #score.append(pbest_y)
    
    return pbest_x, tabu, path_length(pbest_x,distance), score

# %% [markdown]
# # SA

# %%
# =========================== SA ===========================

def SA(distmat):
    num = 36 #城市數量
    distmat = np.asarray(distmat)
    solutionnew = np.arange(num)
    solutioncurrent = solutionnew.copy()
    valuecurrent =99000  
    solutionbest = solutionnew.copy()
    valuebest = 99000 
    iter_ = 60
    result = [] 
    time = 0
    solutions = []
    while time < iter_:
        loc1 = np.int(np.ceil(np.random.rand()*(num-1)))
        loc2 = np.int(np.ceil(np.random.rand()*(num-1)))
        if loc1 != loc2:
            solutionnew[loc1],solutionnew[loc2] = solutionnew[loc2],solutionnew[loc1]
            
        valuenew = 0
        for i in range(num-1):
            valuenew += distmat[solutionnew[i]][solutionnew[i+1]]
        valuenew += distmat[solutionnew[0]][solutionnew[14]]
        if valuenew<valuecurrent: 
            valuecurrent = valuenew
            solutioncurrent = solutionnew.copy()
            if valuenew < valuebest:
                valuebest = valuenew
                solutionbest = solutionnew.copy()
        else:
            if np.random.rand() < np.exp(-(valuenew-valuecurrent)/time):
                valuecurrent = valuenew
                solutioncurrent = solutionnew.copy()
            else:
                solutionnew = solutioncurrent.copy()
                    
        solutions.append(solutionnew)
        time += 1
        result.append(valuebest)
    best_length = min(result)
    best_ = solutions[result.index(best_length)]

    return best_length, best_, result

# %% [markdown]
# # Genetic Algorithm

# %%
import numpy as np
import matplotlib.pyplot as plt 

adjacency_mat = np.asarray(dist_list)

class Population():
    def __init__(self, bag, adjacency_mat):
        self.bag = bag
        self.parents = []
        self.score = 0
        self.best = None
        self.adjacency_mat = adjacency_mat

def init_population(cities, adjacency_mat, n_population):
    return Population(np.asarray([np.random.permutation(cities) for _ in range(n_population)]), adjacency_mat)

def fitness(self, chromosome):
    return sum([ self.adjacency_mat[chromosome[i], chromosome[i + 1]] for i in range(len(chromosome) - 1)])

def evaluate(self):
    distances = np.asarray([self.fitness(chromosome) for chromosome in self.bag])
    self.score = np.min(distances)
    self.best = self.bag[distances.tolist().index(self.score)]
    self.parents.append(self.best)
    if False in (distances[0] == distances):
        distances = np.max(distances) - distances
    return distances / np.sum(distances)

def select(self, k=4):
    fit = self.evaluate()
    while len(self.parents) < k:
        idx = np.random.randint(0, len(fit))
        if fit[idx] > np.random.rand():
            self.parents.append(self.bag[idx])
    self.parents = np.asarray(self.parents)

def swap(chromosome):
    a, b = np.random.choice(len(chromosome), 2)
    chromosome[a], chromosome[b] = (chromosome[b],chromosome[a],)
    return chromosome

def crossover(self, p_cross=0.1):
    children = []
    count, size = self.parents.shape
    for _ in range(len(self.bag)):
        if np.random.rand() > p_cross:
            children.append(list(self.parents[np.random.randint(count, size=1)[0]]))
        else:
            parent1, parent2 = self.parents[np.random.randint(count, size=2), :]
            idx = np.random.choice(range(size), size=2, replace=False)
            start, end = min(idx), max(idx)
            child = [None] * size
            for i in range(start, end + 1, 1):
                child[i] = parent1[i]
            pointer = 0
            for i in range(size):
                if child[i] is None:
                    while parent2[pointer] in child:
                        pointer += 1
                    child[i] = parent2[pointer]
            children.append(child)
    return children

def mutate(self, p_cross=0.1, p_mut=0.1):
    next_bag = []
    children = self.crossover(p_cross)
    for child in children:
        if np.random.rand() < p_mut:
            next_bag.append(swap(child))
        else:
            next_bag.append(child)
    return next_bag
    
def genetic_algorithm(
    cities,
    adjacency_mat,
    n_population=12,
    n_iter=60,
    selectivity=0.15,
    p_cross=0.3,
    p_mut=0.3,
):
    pop = init_population(cities, adjacency_mat, n_population)
    best = pop.best
    score = float("inf")
    history = []
    for i in range(n_iter):
        pop.select(n_population * selectivity)
        history.append(pop.score)
        if pop.score < score:
            best = pop.best
            score = pop.score
        children = pop.mutate(p_cross, p_mut)
        pop = Population(children, pop.adjacency_mat)
    
    return best, history, history[-1]

cities = []
for i in range(36):
    cities.append(i)

pop = init_population(cities, adjacency_mat, 36)

Population.fitness = fitness
Population.evaluate = evaluate
Population.select = select
Population.crossover = crossover
Population.mutate = mutate

# %%
tsp = dist_list
genetic_algorithm(cities, adjacency_mat)
# Out:
# ([31,
#   33,
#   28,
#   26,
#   34,
#   23,
#   20,
#   13,
#   17,
#   2,
#   10,
#   30,
#   35,
#   24,
#   12,
#   19,
#   18,
#   22,
#   21,
#   4,
#   11,
#   6,
#   14,
#   29,
#   1,
#   25,
#   27,
#   16,
#   5,
#   0,
#   3,
#   8,
#   9,
#   32,
#   7,
#   15],
#  [103.16000000000001,
#   103.16000000000001,
#   103.16000000000001,
#   97.96,
#   97.96,
#   97.16,
#   94.16000000000001,
#   93.16000000000001,
#   93.16000000000001,
#   88.66000000000004,
#   86.66000000000001,
#   86.66000000000001,
#   86.66000000000001,
#   83.36000000000001,
#   82.76,
#   82.76,
#   82.76,
#   80.46000000000001,
#   79.36000000000003,
#   79.36000000000003,
#   79.36000000000003,
#   78.96000000000001,
#   78.86,
#   76.86,
#   76.86,
#   72.46000000000001,
#   72.46000000000001,
#   72.46000000000001,
#   72.46000000000001,
#   72.46000000000001,
#   72.46000000000001,
#   72.46000000000001,
#   72.25999999999999,
#   67.96,
#   67.96,
#   67.96,
#   67.96,
#   67.96,
#   67.96,
# ...

# %% [markdown]
# # PSO

# %%
from random import *
import random
import numpy as np
from matplotlib import pyplot
import math
from pprint import pprint

tsp = dist_list


def PSO(distmat):
    num = 36 #城市數量
    distmat = np.asarray(distmat)
    solutionnew = np.arange(num)
    solutioncurrent = solutionnew.copy()
    valuecurrent =99000  
    solutionbest = solutionnew.copy()
    valuebest = 99000 
    iter_ = 60
    result = [] 
    time = 0
    solutions = []

    loc1 = 0
    w = 1
    c1 = 5
    c2 = 5
    best_loc = 0
    
    while time < iter_:
        dist_ = dist_list[loc1]
        sort_dist = dist_list[loc1]
        sort_dist.sort()
        candidate = []
        for i in sort_dist:
            if len(candidate)<=6 and dist_.index(i) not in result and dist_.index(i)!=loc1:
                candidate.append( dist_.index(i) )
                # print(candidate)
        new_pos_ = int(((c1*np.random.random()) + (c2*np.random.random()))*10)
        while new_pos_>= 6:
            new_pos_ = int(((c1*np.random.random()) + (c2*np.random.random()))*10)
        # print(new_pos_)
        loc1 = candidate[new_pos_]
        # loc1 = w*loc1 + int(loc1*c1*np.random.random()) + int(c2*np.random.random())

        if loc1+1 < num and loc1>0: #檢查有無超過範圍
            solutionnew[loc1],solutionnew[loc1+1] = solutionnew[loc1+1],solutionnew[loc1]
            loc1 = loc1+1
        elif loc1<0:
            loc1 = int(np.random.random()*10)
            solutionnew[loc1],solutionnew[loc1+1] = solutionnew[loc1+1],solutionnew[loc1]
        else:
            loc1 = loc1%(num-1)
            solutionnew[loc1],solutionnew[loc1+1] = solutionnew[loc1+1],solutionnew[loc1]
                            
        valuenew = 0
        for i in range(num-1):
            valuenew += distmat[solutionnew[i]][solutionnew[i+1]]
        valuenew += distmat[solutionnew[0]][solutionnew[num-1]]
        if valuenew<valuecurrent: 
            valuecurrent = valuenew
            solutioncurrent = solutionnew.copy()
            if valuenew < valuebest:
                valuebest = valuenew
                solutionbest = solutionnew.copy()
                best_loc = loc1
                    
        solutions.append(solutionnew)
        time += 1
        result.append(valuebest)
    best_length = min(result)
    best_ = solutions[result.index(best_length)]

    return best_length, best_, result

# %% [markdown]
# # Ant

# %%
def ant(distmat):
    distmat = dist_list

    numant = 40  # 螞蟻數
    numcity = 36  # 店家個數
    alpha = 1  # 訊息重要程度因子
    beta = 5  # 啟發函數重要程度因子
    rho = 0.1  # 訊息的消散消失速度
    Q = 1
    iter = 0
    itermax = 60
    etatable = 1.0 / (distmat + np.diag([1e10] * numcity))  # 啟發函數矩陣，表示把已從店家i轉移到矩陣j的期望程度
    pheromonetable = np.ones((numcity, numcity))  # 訊息矩阵
    pathtable = np.zeros((numant, numcity)).astype(int)  # 路徑記錄表
    lengthaver = np.zeros(itermax)  # 各代路徑的平均長度
    lengthbest = np.zeros(itermax)  # 各代及其之前遇到的最佳路徑長度
    pathbest = np.zeros((itermax, numcity))  # 各代及其之前遇到的最佳路徑長度

    while iter < itermax:
        # 隨機選擇一個起點
        if numant <= numcity:  # 店家數比螞蟻數多
            pathtable[:, 0] = np.random.permutation(range(0, numcity))[:numant]
        else:  # 螞蟻數比店家數多
            pathtable[:numcity, 0] = np.random.permutation(range(0, numcity))[:]
            pathtable[numcity:, 0] = np.random.permutation(range(0, numcity))[:numant - numcity]
        length = np.zeros(numant)  # 計算螞蟻的路徑距離
        for i in range(numant):
            visiting = pathtable[i, 0]  # 目前所在店家
            unvisited = set(range(numcity))  # 未訪問的店家
            unvisited.remove(visiting)  # 刪除
            for j in range(1, numcity):  # 循環numcity-1次，訪問剩餘的的numcity-1個店家
                # 用輪盤法選擇下一個要訪問的店家
                listunvisited = list(unvisited)
                probtrans = np.zeros(len(listunvisited))
                for k in range(len(listunvisited)):
                    probtrans[k] = np.power(pheromonetable[visiting][listunvisited[k]], alpha) \
                                * np.power(etatable[visiting][listunvisited[k]], alpha)
                cumsumprobtrans = (probtrans / sum(probtrans)).cumsum()
                cumsumprobtrans -= np.random.rand()
                k = listunvisited[(np.where(cumsumprobtrans > 0)[0])[0]]  
                # 下一輪選的店家
                pathtable[i, j] = k  # 添加至路徑表中
                unvisited.remove(k)  # remove掉將訪問的店家
                length[i] += distmat[visiting][k]
                visiting = k
            length[i] += distmat[visiting][pathtable[i, 0]]  # 最後一個與第一個店家的距離
        lengthaver[iter] = length.mean()
        if iter == 0:
            lengthbest[iter] = length.min()
            pathbest[iter] = pathtable[length.argmin()].copy()
        else:
            if length.min() > lengthbest[iter - 1]:
                lengthbest[iter] = lengthbest[iter - 1]
                pathbest[iter] = pathbest[iter - 1].copy()
            else:
                lengthbest[iter] = length.min()
                pathbest[iter] = pathtable[length.argmin()].copy()
        # 更新訊息
        changepheromonetable = np.zeros((numcity, numcity))
        for i in range(numant):
            for j in range(numcity - 1):
                changepheromonetable[pathtable[i, j]][pathtable[i, j + 1]] += Q / distmat[pathtable[i, j]][
                    pathtable[i, j + 1]]  # 計算訊息增量
            changepheromonetable[pathtable[i, j + 1]][pathtable[i, 0]] += Q / distmat[pathtable[i, j + 1]][pathtable[i, 0]]
        pheromonetable = (1 - rho) * pheromonetable + changepheromonetable  # 計算訊息公式
        iter += 1  

    return pathbest[-1],lengthbest[-1],lengthbest

# %% [markdown]
# # 經緯度轉換

# %%
stores = [{"name": "中坡", "address": "台北市南港區中坡南路47號1樓"},
{"name": "中研", "address": "台北市南港區研究院路二段128號1樓(學術活動中心)"},
{"name": "中貿", "address": "台北市南港區經貿二路186號2樓"},
{"name": "玉成", "address": "台北市南港區西新里南港路三段3號1樓"},
{"name": "玉德", "address": "台北市南港區玉成街150號1樓"},
{"name": "向揚", "address": "台北市南港區向陽路166號1樓"},
{"name": "庄研", "address": "台北市南港區研究院路二段152號"},
{"name": "佳樂", "address": "台北市南港區南港路一段303號305號307號1樓"},
{"name": "忠陽", "address": "台北市南港區忠孝東路六段465號1樓"},
{"name": "昆陽", "address": "台北市南港區忠孝東路六段448號"},
{"name": "林坊", "address": "台北市南港區東新街80巷1號"},
{"name": "研究", "address": "台北市南港區研究院路二段14號"},
{"name": "胡適", "address": "台北市南港區研究院路二段94號96號98巷1號"},
{"name": "重陽", "address": "台北市南港區重陽路179號181號1樓"},
{"name": "香城", "address": "台北市南港區南港路一段167號1樓"},
{"name": "凱松", "address": "台北市南港區八德路四段778號780號"},
{"name": "港泰", "address": "台北市南港區忠孝東路七段359號1樓"},
{"name": "港高鐵", "address": "台北市南港區南港路一段313號B2"},
{"name": "港捷", "address": "台北市南港區經貿二路1號"},
{"name": "港勝", "address": "台北市南港區經貿二路2號B1樓"},
{"name": "港運", "address": "台北市南港區玉成街69號1樓"},
{"name": "港德", "address": "台北市南港區福德街373巷25號"},
{"name": "港興", "address": "台北市南港區興華路119號121號123號125號"},
{"name": "港環球", "address": "台北市南港區忠孝東路七段371號B2"},
{"name": "港麗", "address": "台北市南港區忠孝東路七段369號2樓"},
{"name": "華技", "address": "台北市南港區研究院路三段72號74號1樓"},
{"name": "雄強", "address": "台北市南港區忠孝東路六段276號"},
{"name": "慈愛", "address": "台北市南港區重陽路164號"},
{"name": "新福玉", "address": "台北市南港區成福路145號147號"},
{"name": "經貿", "address": "台北市南港區三重路19號1樓"},
{"name": "聯成", "address": "台北市南港區聯成里昆陽街150-1號150-3號"},
{"name": "聯坊", "address": "台北市南港區東新街118巷1號"},
{"name": "馥樺", "address": "台北市南港區三重路23號1樓"},
{"name": "鵬馳", "address": "台北市南港區南港路三段49-1號"},
{"name": "耀港", "address": "台北市南港區研究院路一段99號1樓之14"},
{"name": "鑫貿", "address": "台北市南港區經貿二路168號4樓"}
]

# %%
address_list = []
for i in range(len(stores)):
    address_list.append(stores[i]["address"])
print(address_list)
# Out:
# ['台北市南港區中坡南路47號1樓', '台北市南港區研究院路二段128號1樓(學術活動中心)', '台北市南港區經貿二路186號2樓', '台北市南港區西新里南港路三段3號1樓', '台北市南港區玉成街150號1樓', '台北市南港區向陽路166號1樓', '台北市南港區研究院路二段152號', '台北市南港區南港路一段303號305號307號1樓', '台北市南港區忠孝東路六段465號1樓', '台北市南港區忠孝東路六段448號', '台北市南港區東新街80巷1號', '台北市南港區研究院路二段14號', '台北市南港區研究院路二段94號96號98巷1號', '台北市南港區重陽路179號181號1樓', '台北市南港區南港路一段167號1樓', '台北市南港區八德路四段778號780號', '台北市南港區忠孝東路七段359號1樓', '台北市南港區南港路一段313號B2', '台北市南港區經貿二路1號', '台北市南港區經貿二路2號B1樓', '台北市南港區玉成街69號1樓', '台北市南港區福德街373巷25號', '台北市南港區興華路119號121號123號125號', '台北市南港區忠孝東路七段371號B2', '台北市南港區忠孝東路七段369號2樓', '台北市南港區研究院路三段72號74號1樓', '台北市南港區忠孝東路六段276號', '台北市南港區重陽路164號', '台北市南港區成福路145號147號', '台北市南港區三重路19號1樓', '台北市南港區聯成里昆陽街150-1號150-3號', '台北市南港區東新街118巷1號', '台北市南港區三重路23號1樓', '台北市南港區南港路三段49-1號', '台北市南港區研究院路一段99號1樓之14', '台北市南港區經貿二路168號4樓']

# %%
add = pd.DataFrame(address_list)#, columns="address")
import csv
print(type(add))
add.to_csv("add.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import codecs
f = codecs.open("add.txt", 'r', 'utf-8') #記得以utf-8開啟文字檔
location = f.read()
f.close()

places = tuple(location.split('\n'))
URL = []
for i in places:
    URL.append("https://www.google.com/maps/place?q=" + i)
    
from openpyxl import Workbook
wb = Workbook()
ws = wb.active
ws['A1'] = 'longitude'
ws['B1'] = 'latitude'

def STR_to_NUM(data):
    line = tuple(data.split(',')) #註1
    num1 = float(line[1])
    num2 = float(line[2])
    line = [num1, num2]
    return line

import requests
from bs4 import BeautifulSoup
def coordination(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    text = soup.prettify() #text 包含了html的內容
    initial_pos = text.find(";window.APP_INITIALIZATION_STATE")
    #尋找;window.APP_INITIALIZATION_STATE所在位置
    data = text[initial_pos+36:initial_pos+85] #將其後的參數進行存取
    num_data = STR_to_NUM(data)
    ws.append(num_data) #將經緯度存到Excel裡
    
def STR_to_NUM(data):
    line = (data.split(','))
    num1 = float(line[1])
    num2 = float(line[2])
    line = [num1, num2]
    return line

import requests
from bs4 import BeautifulSoup
for i in URL:
    coordination(i)
    print(i)
    wb.save('loc.csv') #自行決定檔名
# Out:
# https://www.google.com/maps/place?q=台北市南港區中坡南路47號1樓
# https://www.google.com/maps/place?q=台北市南港區研究院路二段128號1樓(學術活動中心)
# https://www.google.com/maps/place?q=台北市南港區經貿二路186號2樓
# https://www.google.com/maps/place?q=台北市南港區西新里南港路三段3號1樓
# https://www.google.com/maps/place?q=台北市南港區玉成街150號1樓
# https://www.google.com/maps/place?q=台北市南港區向陽路166號1樓
# https://www.google.com/maps/place?q=台北市南港區研究院路二段152號
# https://www.google.com/maps/place?q=台北市南港區南港路一段303號305號307號1樓
# https://www.google.com/maps/place?q=台北市南港區忠孝東路六段465號1樓
# https://www.google.com/maps/place?q=台北市南港區忠孝東路六段448號
# https://www.google.com/maps/place?q=台北市南港區東新街80巷1號
# https://www.google.com/maps/place?q=台北市南港區研究院路二段14號
# https://www.google.com/maps/place?q=台北市南港區研究院路二段94號96號98巷1號
# https://www.google.com/maps/place?q=台北市南港區重陽路179號181號1樓
# https://www.google.com/maps/place?q=台北市南港區南港路一段167號1樓
# https://www.google.com/maps/place?q=台北市南港區八德路四段778號780號
# https://www.google.com/maps/place?q=台北市南港區忠孝東路七段359號1樓
# ...

# %% [markdown]
# # Bonus - Cuckoo Search Algorithm

# %%
from random import uniform
from random import randint 
import math

distanceMatrix = dist_list

def levyFlight(u):
    return math.pow(u,-1.0/3.0)

def randF():
    return uniform(0.0001,0.9999)

def calculateDistance(path):
    index = path[0]
    distance = 0
    for nextIndex in path[1:]:
        distance += distanceMatrix[index][nextIndex]
        index = nextIndex
    return distance+distanceMatrix[path[-1]][path[0]];

def Swap(sequence,i,j):
    temp = sequence[i]
    sequence[i]=sequence[j]
    sequence[j]=temp

def twoOptMove(nest,a,c):
    nest = nest[0][:]
    Swap(nest,a,c)
    return (nest,calculateDistance(nest))
	

def doubleBridgeMove(nest,a,b,c,d):
    nest = nest[0][:]
    Swap(nest,a,b)
    Swap(nest,b,d)
    return (nest , calculateDistance(nest))

def cuckoo(distanceMatrix):
    numNests = 80
    pa = int(0.5*numNests)
    pc = int(0.6*numNests)

    maxGen = 60
    n = len(distanceMatrix)

    nests = []
    result = []
    best_ = 9999999

    initPath=list(range(0,n))
    index = 0
    for i in range(numNests):
        if index == n-1:
            index = 0
        Swap(initPath,index,index+1)
        index+=1
        nests.append((initPath[:],calculateDistance(initPath)))
        if best_ > calculateDistance(initPath):
                best_ = calculateDistance(initPath)
	

    nests.sort(key=lambda tup: tup[1])

    for t in range(maxGen):
        cuckooNest = nests[randint(0,pc)]
        if math.pow(randF(),-1.0/3.0>2):
            cuckooNest = doubleBridgeMove(cuckooNest,randint(0,n-1), randint(0,n-1), randint(0,n-1), randint(0,n-1))
            if best_ > cuckooNest[1]:
                best_ = cuckooNest[1]
        else:
            cuckooNest = twoOptMove(cuckooNest, randint(0,n-1), randint(0,n-1), randint(0,n-1), randint(0,n-1))
            if best_ > cuckooNest[1]:
                best_ = cuckooNest[1]
        randomNestIndex = randint(0,numNests-1)
        if nests[randomNestIndex][1]>cuckooNest[1] :
            nests[randomNestIndex] = cuckooNest
        for i in range(numNests-pa, numNests):
            nests[i] = twoOptMove(nests[i], randint(0,n-1), randint(0,n-1))
            #print(nests[i][1])
            if best_ > nests[i][1]:
                best_ = nests[i][1]
        result.append(best_)
        nests.sort(key=lambda tup: tup[1])
    
    return nests[0][0], nests[0][1], result

# %%
print(cuckoo(dist_list))
# Out:
# ([3, 6, 5, 4, 7, 8, 9, 24, 11, 12, 2, 13, 26, 15, 16, 10, 18, 19, 23, 35, 22, 20, 17, 25, 27, 30, 28, 29, 14, 31, 32, 33, 34, 21, 0, 1], 88.85999999999999, [108.36000000000001, 104.96000000000001, 101.55999999999999, 101.55999999999999, 101.55999999999999, 101.55999999999999, 96.86, 96.86, 96.86, 96.86, 96.86, 96.86, 96.86, 96.86, 96.86, 96.86, 96.86, 96.86, 96.86, 96.86, 96.86, 96.86, 93.76000000000002, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 88.85999999999999, 8
# ...

# %% [markdown]
# # All Final Comparisons

# %%
def main():
    city = store_name
    tsp = dist_list

    currentSolution, bestNeighbourRouteLength, result = hillClimbing(tsp)
    BEST, BEST_LENGTH, result2 = random_walk(tsp)
    pbest_x, tabu, best_length, result3 = tabu_search(tsp)
    best_length, best_, result4 = SA(tsp)
    pathbest_, lengthbest_, result5 = ant(tsp)
    best_length6, best_6, result6 = PSO(tsp)
    path_best7, result7, best_length7 = genetic_algorithm(cities, adjacency_mat)
    path_best8, best_length8, result8 = cuckoo(tsp)

    print("Hill Climbing:")
    print("最佳路線：",currentSolution)
    print("最佳路線長度：",bestNeighbourRouteLength)

    print("Random Walk:")
    print("最佳路線：", BEST)
    print("最佳路線長度：", BEST_LENGTH)

    print("Tabu Search:")
    print("最佳路線：", pbest_x)
    print("最佳路線長度：", best_length)
    print("Tabu List：", tabu)
    
    print("Genetic Algorithm:")
    print("最佳路線：", path_best7)
    print("最佳路線長度：", best_length7)

    print("Simulated Annealing:")
    print("最佳路線：", best_)
    print("最佳路線長度：", best_length)
    
    print("Ant Colony:")
    print("最佳路線：", pathbest_)
    print("最佳路線長度：", lengthbest_)
    
    print("PSO:")
    print("最佳路線：", best_6)
    print("最佳路線長度：", best_length6)
    
    print("Cuckoo:")
    print("最佳路線：", path_best8)
    print("最佳路線長度：", best_length8)
    
    # line plot of best scores  
    pyplot.plot(result, '.-', label = "Hill climbing")
    pyplot.plot(result2, '.-', label = "Random walk")
    pyplot.plot(result3, '.-', label = "Tabu search")
    pyplot.plot(result4, '.-', label = "SA")
    pyplot.plot(result5, '.-', label = "Ant Colony")
    pyplot.plot(result6, '.-', label = "PSO")
    pyplot.plot(result7, '.-', label = "Genetic")
    pyplot.legend(bbox_to_anchor=(1.05, 1.0),loc='best')
    pyplot.xlabel('Iterations')  
    pyplot.ylabel('Evaluation f(x)')  
    pyplot.show()
    
    # line plot of best scores  
    pyplot.plot(result, '.-', label = "Hill climbing")
    pyplot.plot(result2, '.-', label = "Random walk")
    pyplot.plot(result3, '.-', label = "Tabu search")
    pyplot.plot(result4, '.-', label = "SA")
    pyplot.plot(result5, '.-', label = "Ant Colony")
    pyplot.plot(result6, '.-', label = "PSO")
    pyplot.plot(result7, '.-', label = "Genetic")
    pyplot.plot(result8, '.-', label = "Cuckoo")
    pyplot.legend(bbox_to_anchor=(1.05, 1.0),loc='best')
    pyplot.xlabel('Iterations')  
    pyplot.ylabel('Evaluation f(x)')  
    pyplot.show()
    
    return currentSolution,BEST,pbest_x,best_,pathbest_,best_6,path_best7, path_best8

# %%
ans1,ans2,ans3,ans4,ans5,ans6,ans7,ans8 = main()
# Out:
# Hill Climbing:
# 最佳路線： [8, 12, 19, 22, 30, 32, 28, 6, 34, 25, 7, 26, 23, 16, 9, 13, 14, 1, 2, 11, 18, 27, 35, 17, 8, 15, 31, 10, 5, 4, 21, 29, 3, 33, 24, 20]
# 最佳路線長度： 80.5
# Random Walk:
# 最佳路線： [8, 14, 9, 26, 2, 15, 30, 29, 13, 25, 6, 31, 11, 12, 22, 32, 8, 16, 3, 28, 27, 18, 35, 7, 34, 24, 33, 4, 23, 19, 20, 17, 21, 5, 10, 1]
# 最佳路線長度： 105.49999999999999
# Tabu Search:
# 最佳路線： [0, 21, 27, 16, 4, 13, 23, 29, 14, 11, 19, 6, 18, 7, 3, 22, 32, 24, 5, 31, 33, 10, 30, 9, 8, 17, 28, 20, 2, 12, 34, 15, 26, 1, 25, 35]
# 最佳路線長度： 103.5
# Tabu List： [[33, 34], [23, 30], [13, 28], [15, 22], [15, 20], [24, 30]]
# Genetic Algorithm:
# 最佳路線： [2, 3, 18, 16, 10, 31, 8, 29, 22, 5, 12, 35, 7, 1, 14, 25, 11, 33, 23, 34, 4, 9, 20, 30, 21, 32, 27, 17, 26, 28, 15, 0, 6, 13, 24, 19]
# 最佳路線長度： 70.7
# Simulated Annealing:
# 最佳路線： [ 0  3 29 21 31 19 28 23  1 17 12 35  6 25  5 15 34  9 14 13 11 27 16 18
#  30 26  8  7 10 20  4 24 22 33  2 32]
# 最佳路線長度： 103.5
# Ant Colony:
# ...

# %% [markdown]
# # Map 地圖

# %%
loc_df = pd.read_csv("loc1.csv")
latitude_list = list(loc_df["latitude"])
longitude_list = list(loc_df["longitude"])

# %%
def map_(ans,latitude_list,longitude_list,s):
    now_lat = []
    now_long = []
    for i in ans1:
        now_lat.append(latitude_list[i])
        now_long.append(longitude_list[i])
    # import gmplot package
    import gmplot
    latitude_list = list(loc_df["latitude"])
    longitude_list = list(loc_df["longitude"])
    gmap3 = gmplot.GoogleMapPlotter(25.052296,121.614154, 15)
    gmap3.scatter( latitude_list, longitude_list, '# FF0000',
                                size = 40, marker = False )
    gmap3.plot(latitude_list, longitude_list,
            'cornflowerblue', edge_width = 2.5)
    gmap3.draw( "./"+s+"_map.html" )
    return

# %%
map_(ans1,latitude_list,longitude_list,"hillClimbing")
map_(ans2,latitude_list,longitude_list,"randomWalk")
map_(ans3,latitude_list,longitude_list,"tabu")
map_(ans4,latitude_list,longitude_list,"SA")
map_(ans5,latitude_list,longitude_list,"ant")
map_(ans6,latitude_list,longitude_list,"PSO")
map_(ans7,latitude_list,longitude_list,"GA")
map_(ans8,latitude_list,longitude_list,"Cuckoo")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/gmplot/color.py:194: UserWarning: Color '# FF0000' isn't supported.
#   warnings.warn("Color '%s' isn't supported." % color)
